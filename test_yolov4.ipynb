# %%
import torch, torchvision
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.set_printoptions(sci_mode=False, precision=4)
import torchvision.ops as ops

import numpy as np
np.random.seed(0)

from darknet2pytorch import *

from PIL import Image, ImageDraw

# %%
model = darknet.Darknet("./cfg/yolov4.cfg").cuda()
model.load_weights('e:/weights/darknet/yolov4.weights')
img_size = (608,608)

# %%
def post_processing(output, thres_conf=0.5, thres_nms=0.5):
    #do nms
    result = []
    # print(output.shape)
    for i, pred in enumerate(output):
        #print(pred.shape) #torch.Size([10647, 85])
        pred = pred[pred[:, 4] > thres_conf]
        # if pred.nelement() == 0:
        #     continue
        # print(pred.shape)
        x_min = (pred[:, 0:1] - pred[:, 2:3] / 2.0)
        y_min = (pred[:, 1:2] - pred[:, 3:4] / 2.0)
        x_max = (pred[:, 0:1] + pred[:, 2:3] / 2.0)
        y_max = (pred[:, 1:2] + pred[:, 3:4] / 2.0)

        pred_xyxy = torch.cat((x_min, y_min, x_max, y_max), dim=1)
        pred_score, pred_cls_idx = torch.max(pred[:, 5:], 1, keepdim=True)

        keep = ops.boxes.batched_nms(pred_xyxy, pred_score[:, 0],
                                     pred_cls_idx[:, 0], thres_nms)
        pred = torch.cat((pred_xyxy, pred_score, pred_cls_idx.float()),
                         1)[keep]

        batch_num = (torch.ones(pred.shape[0], 1) * i).cuda()
        pred = torch.cat((pred, batch_num), dim=1)
        result.append(pred)

    if not result:
        return torch.zeros(1, 7).fill_(255)
    else:
        return torch.cat(result, dim=0)

# %%
mean = (0.485, 0.456, 0.406)
std = (0.229, 0.224, 0.225)
# t = torchvision.transforms.Compose([torchvision.transforms.Resize(img_size),
#                                     torchvision.transforms.ToTensor(),
#                                     torchvision.transforms.Normalize(mean,std)])
t = torchvision.transforms.Compose([torchvision.transforms.Resize(img_size),
                                    torchvision.transforms.ToTensor()])

# %%
def load_classes(path):
    #Loads class labels at 'path'
    fp = open(path, "r")
    return fp.read().split("\n")[:-1]
classes = load_classes("./data/coco_names.txt")
def draw_boxes(img, boxes, conf, cls):
    #img : PIL Image
    #boxes : N x 4, (x_min,y_min, x_max,y_max)
    #conf : N, confidence score
    #cls :  N, class number
    box_img = ImageDraw.Draw(img)
    
    for box, conf_, cls_ in zip(boxes.cpu(), conf.cpu(), cls.cpu()):
        box_img.rectangle(list(box.data), outline="red")
        box_img.text((box[0], box[1]), classes[int(cls_)], (255,0,0))
    return img

# %%
model.eval()
# Out:
# Darknet(
#   (module_list): ModuleList(
#     (0): Sequential(
#       (conv_0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_0): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_0): Mish()
#     )
#     (1): Sequential(
#       (conv_1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_1): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_1): Mish()
#     )
#     (2): Sequential(
#       (conv_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_2): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_2): Mish()
#     )
#     (3): Sequential(
#       (route_3): EmptyLayer()
#     )
#     (4): Sequential(
#       (conv_4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_4): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_4): Mish()
#     )
#     (5): Sequential(
#       (conv_5): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_5): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_5): Mish()
#     )
#     (6): Sequential(
#       (conv_6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_6): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_6): Mish()
#     )
#     (7): Sequential(
#       (shortcut_7): EmptyLayer()
#     )
#     (8): Sequential(
#       (conv_8): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_8): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_8): Mish()
#     )
#     (9): Sequential(
#       (route_9): EmptyLayer()
#     )
#     (10): Sequential(
#       (conv_10): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_10): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_10): Mish()
#     )
#     (11): Sequential(
#       (conv_11): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_11): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_11): Mish()
#     )
#     (12): Sequential(
#       (conv_12): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_12): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_12): Mish()
#     )
#     (13): Sequential(
#       (route_13): EmptyLayer()
#     )
#     (14): Sequential(
#       (conv_14): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_14): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_14): Mish()
#     )
#     (15): Sequential(
#       (conv_15): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_15): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_15): Mish()
#     )
#     (16): Sequential(
#       (conv_16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_16): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_16): Mish()
#     )
#     (17): Sequential(
#       (shortcut_17): EmptyLayer()
#     )
#     (18): Sequential(
#       (conv_18): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_18): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_18): Mish()
#     )
#     (19): Sequential(
#       (conv_19): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_19): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_19): Mish()
#     )
#     (20): Sequential(
#       (shortcut_20): EmptyLayer()
#     )
#     (21): Sequential(
#       (conv_21): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_21): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_21): Mish()
#     )
#     (22): Sequential(
#       (route_22): EmptyLayer()
#     )
#     (23): Sequential(
#       (conv_23): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_23): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_23): Mish()
#     )
#     (24): Sequential(
#       (conv_24): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_24): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_24): Mish()
#     )
#     (25): Sequential(
#       (conv_25): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_25): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_25): Mish()
#     )
#     (26): Sequential(
#       (route_26): EmptyLayer()
#     )
#     (27): Sequential(
#       (conv_27): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_27): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_27): Mish()
#     )
#     (28): Sequential(
#       (conv_28): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_28): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_28): Mish()
#     )
#     (29): Sequential(
#       (conv_29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_29): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_29): Mish()
#     )
#     (30): Sequential(
#       (shortcut_30): EmptyLayer()
#     )
#     (31): Sequential(
#       (conv_31): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_31): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_31): Mish()
#     )
#     (32): Sequential(
#       (conv_32): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_32): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_32): Mish()
#     )
#     (33): Sequential(
#       (shortcut_33): EmptyLayer()
#     )
#     (34): Sequential(
#       (conv_34): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_34): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_34): Mish()
#     )
#     (35): Sequential(
#       (conv_35): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_35): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_35): Mish()
#     )
#     (36): Sequential(
#       (shortcut_36): EmptyLayer()
#     )
#     (37): Sequential(
#       (conv_37): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_37): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_37): Mish()
#     )
#     (38): Sequential(
#       (conv_38): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_38): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_38): Mish()
#     )
#     (39): Sequential(
#       (shortcut_39): EmptyLayer()
#     )
#     (40): Sequential(
#       (conv_40): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_40): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_40): Mish()
#     )
#     (41): Sequential(
#       (conv_41): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_41): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_41): Mish()
#     )
#     (42): Sequential(
#       (shortcut_42): EmptyLayer()
#     )
#     (43): Sequential(
#       (conv_43): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_43): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_43): Mish()
#     )
#     (44): Sequential(
#       (conv_44): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_44): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_44): Mish()
#     )
#     (45): Sequential(
#       (shortcut_45): EmptyLayer()
#     )
#     (46): Sequential(
#       (conv_46): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_46): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_46): Mish()
#     )
#     (47): Sequential(
#       (conv_47): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_47): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_47): Mish()
#     )
#     (48): Sequential(
#       (shortcut_48): EmptyLayer()
#     )
#     (49): Sequential(
#       (conv_49): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_49): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_49): Mish()
#     )
#     (50): Sequential(
#       (conv_50): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_50): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_50): Mish()
#     )
#     (51): Sequential(
#       (shortcut_51): EmptyLayer()
#     )
#     (52): Sequential(
#       (conv_52): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_52): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_52): Mish()
#     )
#     (53): Sequential(
#       (route_53): EmptyLayer()
#     )
#     (54): Sequential(
#       (conv_54): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_54): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_54): Mish()
#     )
#     (55): Sequential(
#       (conv_55): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_55): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_55): Mish()
#     )
#     (56): Sequential(
#       (conv_56): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_56): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_56): Mish()
#     )
#     (57): Sequential(
#       (route_57): EmptyLayer()
#     )
#     (58): Sequential(
#       (conv_58): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_58): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_58): Mish()
#     )
#     (59): Sequential(
#       (conv_59): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_59): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_59): Mish()
#     )
#     (60): Sequential(
#       (conv_60): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_60): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_60): Mish()
#     )
#     (61): Sequential(
#       (shortcut_61): EmptyLayer()
#     )
#     (62): Sequential(
#       (conv_62): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_62): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_62): Mish()
#     )
#     (63): Sequential(
#       (conv_63): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_63): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_63): Mish()
#     )
#     (64): Sequential(
#       (shortcut_64): EmptyLayer()
#     )
#     (65): Sequential(
#       (conv_65): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_65): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_65): Mish()
#     )
#     (66): Sequential(
#       (conv_66): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_66): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_66): Mish()
#     )
#     (67): Sequential(
#       (shortcut_67): EmptyLayer()
#     )
#     (68): Sequential(
#       (conv_68): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_68): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_68): Mish()
#     )
#     (69): Sequential(
#       (conv_69): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_69): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_69): Mish()
#     )
#     (70): Sequential(
#       (shortcut_70): EmptyLayer()
#     )
#     (71): Sequential(
#       (conv_71): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_71): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_71): Mish()
#     )
#     (72): Sequential(
#       (conv_72): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_72): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_72): Mish()
#     )
#     (73): Sequential(
#       (shortcut_73): EmptyLayer()
#     )
#     (74): Sequential(
#       (conv_74): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_74): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_74): Mish()
#     )
#     (75): Sequential(
#       (conv_75): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_75): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_75): Mish()
#     )
#     (76): Sequential(
#       (shortcut_76): EmptyLayer()
#     )
#     (77): Sequential(
#       (conv_77): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_77): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_77): Mish()
#     )
#     (78): Sequential(
#       (conv_78): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_78): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_78): Mish()
#     )
#     (79): Sequential(
#       (shortcut_79): EmptyLayer()
#     )
#     (80): Sequential(
#       (conv_80): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_80): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_80): Mish()
#     )
#     (81): Sequential(
#       (conv_81): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_81): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_81): Mish()
#     )
#     (82): Sequential(
#       (shortcut_82): EmptyLayer()
#     )
#     (83): Sequential(
#       (conv_83): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_83): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_83): Mish()
#     )
#     (84): Sequential(
#       (route_84): EmptyLayer()
#     )
#     (85): Sequential(
#       (conv_85): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_85): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_85): Mish()
#     )
#     (86): Sequential(
#       (conv_86): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_86): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_86): Mish()
#     )
#     (87): Sequential(
#       (conv_87): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_87): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_87): Mish()
#     )
#     (88): Sequential(
#       (route_88): EmptyLayer()
#     )
#     (89): Sequential(
#       (conv_89): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_89): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_89): Mish()
#     )
#     (90): Sequential(
#       (conv_90): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_90): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_90): Mish()
#     )
#     (91): Sequential(
#       (conv_91): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_91): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_91): Mish()
#     )
#     (92): Sequential(
#       (shortcut_92): EmptyLayer()
#     )
#     (93): Sequential(
#       (conv_93): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_93): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_93): Mish()
#     )
#     (94): Sequential(
#       (conv_94): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_94): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_94): Mish()
#     )
#     (95): Sequential(
#       (shortcut_95): EmptyLayer()
#     )
#     (96): Sequential(
#       (conv_96): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_96): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_96): Mish()
#     )
#     (97): Sequential(
#       (conv_97): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_97): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_97): Mish()
#     )
#     (98): Sequential(
#       (shortcut_98): EmptyLayer()
#     )
#     (99): Sequential(
#       (conv_99): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_99): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_99): Mish()
#     )
#     (100): Sequential(
#       (conv_100): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_100): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_100): Mish()
#     )
#     (101): Sequential(
#       (shortcut_101): EmptyLayer()
#     )
#     (102): Sequential(
#       (conv_102): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_102): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_102): Mish()
#     )
#     (103): Sequential(
#       (route_103): EmptyLayer()
#     )
#     (104): Sequential(
#       (conv_104): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_104): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (mish_104): Mish()
#     )
#     (105): Sequential(
#       (conv_105): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_105): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_105): LeakyReLU(negative_slope=0.1)
#     )
#     (106): Sequential(
#       (conv_106): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_106): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_106): LeakyReLU(negative_slope=0.1)
#     )
#     (107): Sequential(
#       (conv_107): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_107): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_107): LeakyReLU(negative_slope=0.1)
#     )
#     (108): Sequential(
#       (maxpool_108): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (109): Sequential(
#       (route_109): EmptyLayer()
#     )
#     (110): Sequential(
#       (maxpool_110): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#     )
#     (111): Sequential(
#       (route_111): EmptyLayer()
#     )
#     (112): Sequential(
#       (maxpool_112): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#     )
#     (113): Sequential(
#       (route_113): EmptyLayer()
#     )
#     (114): Sequential(
#       (conv_114): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_114): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_114): LeakyReLU(negative_slope=0.1)
#     )
#     (115): Sequential(
#       (conv_115): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_115): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_115): LeakyReLU(negative_slope=0.1)
#     )
#     (116): Sequential(
#       (conv_116): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_116): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_116): LeakyReLU(negative_slope=0.1)
#     )
#     (117): Sequential(
#       (conv_117): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_117): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_117): LeakyReLU(negative_slope=0.1)
#     )
#     (118): Sequential(
#       (upsample_118): Upsample()
#     )
#     (119): Sequential(
#       (route_119): EmptyLayer()
#     )
#     (120): Sequential(
#       (conv_120): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_120): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_120): LeakyReLU(negative_slope=0.1)
#     )
#     (121): Sequential(
#       (route_121): EmptyLayer()
#     )
#     (122): Sequential(
#       (conv_122): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_122): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_122): LeakyReLU(negative_slope=0.1)
#     )
#     (123): Sequential(
#       (conv_123): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_123): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_123): LeakyReLU(negative_slope=0.1)
#     )
#     (124): Sequential(
#       (conv_124): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_124): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_124): LeakyReLU(negative_slope=0.1)
#     )
#     (125): Sequential(
#       (conv_125): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_125): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_125): LeakyReLU(negative_slope=0.1)
#     )
#     (126): Sequential(
#       (conv_126): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_126): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_126): LeakyReLU(negative_slope=0.1)
#     )
#     (127): Sequential(
#       (conv_127): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_127): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_127): LeakyReLU(negative_slope=0.1)
#     )
#     (128): Sequential(
#       (upsample_128): Upsample()
#     )
#     (129): Sequential(
#       (route_129): EmptyLayer()
#     )
#     (130): Sequential(
#       (conv_130): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_130): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_130): LeakyReLU(negative_slope=0.1)
#     )
#     (131): Sequential(
#       (route_131): EmptyLayer()
#     )
#     (132): Sequential(
#       (conv_132): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_132): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_132): LeakyReLU(negative_slope=0.1)
#     )
#     (133): Sequential(
#       (conv_133): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_133): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_133): LeakyReLU(negative_slope=0.1)
#     )
#     (134): Sequential(
#       (conv_134): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_134): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_134): LeakyReLU(negative_slope=0.1)
#     )
#     (135): Sequential(
#       (conv_135): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_135): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_135): LeakyReLU(negative_slope=0.1)
#     )
#     (136): Sequential(
#       (conv_136): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_136): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_136): LeakyReLU(negative_slope=0.1)
#     )
#     (137): Sequential(
#       (conv_137): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_137): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_137): LeakyReLU(negative_slope=0.1)
#     )
#     (138): Sequential(
#       (conv_138): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (139): Sequential(
#       (yolo_layer_139): DarknetYOLOLayer()
#     )
#     (140): Sequential(
#       (route_140): EmptyLayer()
#     )
#     (141): Sequential(
#       (conv_141): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_141): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_141): LeakyReLU(negative_slope=0.1)
#     )
#     (142): Sequential(
#       (route_142): EmptyLayer()
#     )
#     (143): Sequential(
#       (conv_143): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_143): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_143): LeakyReLU(negative_slope=0.1)
#     )
#     (144): Sequential(
#       (conv_144): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_144): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_144): LeakyReLU(negative_slope=0.1)
#     )
#     (145): Sequential(
#       (conv_145): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_145): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_145): LeakyReLU(negative_slope=0.1)
#     )
#     (146): Sequential(
#       (conv_146): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_146): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_146): LeakyReLU(negative_slope=0.1)
#     )
#     (147): Sequential(
#       (conv_147): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_147): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_147): LeakyReLU(negative_slope=0.1)
#     )
#     (148): Sequential(
#       (conv_148): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_148): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_148): LeakyReLU(negative_slope=0.1)
#     )
#     (149): Sequential(
#       (conv_149): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (150): Sequential(
#       (yolo_layer_150): DarknetYOLOLayer()
#     )
#     (151): Sequential(
#       (route_151): EmptyLayer()
#     )
#     (152): Sequential(
#       (conv_152): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batch_norm_152): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_152): LeakyReLU(negative_slope=0.1)
#     )
#     (153): Sequential(
#       (route_153): EmptyLayer()
#     )
#     (154): Sequential(
#       (conv_154): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_154): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_154): LeakyReLU(negative_slope=0.1)
#     )
#     (155): Sequential(
#       (conv_155): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_155): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_155): LeakyReLU(negative_slope=0.1)
#     )
#     (156): Sequential(
#       (conv_156): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_156): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_156): LeakyReLU(negative_slope=0.1)
#     )
#     (157): Sequential(
#       (conv_157): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_157): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_157): LeakyReLU(negative_slope=0.1)
#     )
#     (158): Sequential(
#       (conv_158): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_158): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_158): LeakyReLU(negative_slope=0.1)
#     )
#     (159): Sequential(
#       (conv_159): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_159): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_159): LeakyReLU(negative_slope=0.1)
#     )
#     (160): Sequential(
#       (conv_160): Conv2d(1024, 255, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (161): Sequential(
#       (yolo_layer_161): DarknetYOLOLayer()
#     )
#   )
# )

# %%
img1 = Image.open("./imgs/giraffe.jpg")
# img1 = Image.open("e:/test3.jpg")

t_img1 = t(img1).unsqueeze(0).cuda()
img1 = img1.resize(img_size)
with torch.no_grad():
    out = model(t_img1)
print(out[0][out[0,:,4]>0.1][0:, :5])

out_ = post_processing(out)
# Out:
# Sequential(
#   (yolo_layer_139): DarknetYOLOLayer()
# )
# Sequential(
#   (yolo_layer_150): DarknetYOLOLayer()
# )
# Sequential(
#   (yolo_layer_161): DarknetYOLOLayer()
# )
# tensor([[  410.2680,   381.2963,   219.7500,   289.5118,     0.7581],
#         [  408.8797,   395.5555,   218.8311,   300.5376,     0.9852],
#         [  418.9447,   395.7192,   209.9487,   294.7308,     0.7078],
#         [  369.4515,   250.3628,   337.7918,   444.7126,     0.3411],
#         [  349.2162,   278.4909,   331.7515,   489.2436,     0.4360],
#         [  366.4009,   279.3006,   334.1434,   494.9427,     0.9953],
#         [  389.7399,   275.4116,   385.2438,   481.5407,     0.6323],
#         [  349.1019,   292.7910,   351.7927,   535.6463,     0.1733],
#         [  363.6888,   293.8158,   334.2851,   515.2578,     0.9834],
#         [  409.9787,   381.3286,   219.8574,   293.5498,     0.7961],
#         [  408.7311,   395.3598,   218.4678,   299.4402,     0.9877],
#         [  418.9955,   395.6868,   210.2320,   296.0033,     0.7494],
#         [  369.3280,   249.9088,   333.2407,   443.9225,     0.3886],
#         [  349.5605,   278.7673,   338.1801,   494.8909,     0.5064],
#         [  366.5670,   279.1508,   330.5032,   492.7241,     0.9966],
#         [  389.8124,   276.0079,   369.2947,   480.0777,     0.6830],
#         [  349.4445,   293.3599,   349.4873,   524.7297,     0.2458],
#         [  363.6435,   294.0378,   328.6425,   510.1101,     0.9859],
#         [  390.5299,   296.8586,   366.4863,   498.0705,     0.1114],
#         [  410.5171,   381.2422,   219.7849,   294.0511,     0.7956],
#         [  408.8714,   394.8004,   218.5734,   302.6657,     0.9864],
#         [  418.6585,   395.1654,   213.1309,   298.8554,     0.7430],
#         [  408.7686,   419.3850,   210.3271,   312.0986,     0.1048]],
#        device='cuda:0')

# %%
imgs = [img1]
imgs[0] = draw_boxes(imgs[0], out_[:, :4], out_[:, 4], out_[:, 5])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.subplot(221)
plt.imshow(imgs[0])
